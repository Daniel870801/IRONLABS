# %%
import requests
import pandas as pd

response=requests.get('https://xkcd.com')
response
# Out:
# <Response [200]>

# %%
#get it via API
receive=requests.get('https://imgs.xkcd.com/comics/in_ur_reality.png')

# %%
with open(r'C:\Users\lenovo\Desktop\ironhack\API\image.png','wb') as f:
    f.write(receive.content)

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3059', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Tue, 01 Mar 2022 02:27:55 GMT', 'ETag': 'W/"621d84ab-1e79"', 'Expires': 'Tue, 01 Mar 2022 02:33:43 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Tue, 01 Mar 2022 08:07:04 GMT', 'Age': '133', 'X-Served-By': 'cache-dfw18672-DFW, cache-cdg20746-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '2, 1', 'X-Timer': 'S1646122025.832125,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
response.headers['Expires']
# Out:
# 'Tue, 01 Mar 2022 02:33:43 GMT'

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: For the Sake of Simplicity</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="For the Sake of Simplicity">\n<meta property="og:url" content="https://xkcd.com/2587/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/for_the_sake_of_simplicity_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>
# ...

# %%
response2=requests.get('https://httpbin.org/get',params={'things':2,'total':25}) #when I use get, I use params

# %%
response2.content
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-621dd429-08328bb8543322dd62e5c519"\n  }, \n  "origin": "195.134.167.217", \n  "url": "https://httpbin.org/get?things=2&total=25"\n}\n'

# %%
ploads={'Username':'Daniel','Password':'Ironhack'}

# %%
r=requests.post('https://httpbin.org/post',data=ploads) #when I use post, I use data instead of params

# %%
response_dict=r.json()

# %%
print(response_dict['form'])
# Out:
# {'Password': 'Ironhack', 'Username': 'Daniel'}

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
type(search)
# Out:
# dict

# %%
search['items']
# Out:
# [{'name': '.0016.scavengerhunt',
#   'path': '47222/.0016.scavengerhunt',
#   'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
pip install pathlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ruamel-yaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# ...
#
# ...

# %%
import tweepy
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAACXpZgEAAAAA23SiMgVzcRZO3l1ZaT7CZk0RFXU%3DQvqp85JU6n0Xk9UVEelN4nTfB4Xz8Lc9CGKCcLV7UAmNofxPew')

query = 'Evangelion'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# @Leh_EVANGELION
# 使ってくれてありがとう！あどたん💫.img  -愛梨-さんの動画をダウンロードできるリンクはここだよ。
# https://t.co/hoTD0z4gpV
# RT @Kiritokun01Kun: se ha revelado  que Evangelion: 3.0+1.0 Thrice Upon a Time  ha ganado a "Mejor obra de animación" en la 45° entrega de…
# [{'domain': {'id': '130', 'name': 'Multimedia Franchise', 'description': "Franchises which span multiple forms of media like 'Harry Potter'"}, 'entity': {'id': '1010244637770985472', 'name': 'Neon Genesis Evangelion', 'description': 'Neon Genesis Evangelion (新世紀エヴァンゲリオン)'}}]
# @Engineeredd No, it turns to Neon Genesis Evangelion
# [{'domain': {'id': '130', 'name': 'Multimedia Franchise', 'description': "Franchises which span multiple forms of media like 'Harry Potter'"}, 'entity': {'id': '1010244637770985472', 'name': 'Neon Genesis Evangelion', 'description': 'Neon Genesis Evangelion (新世紀エヴァンゲリオン)'}}]
# meine kollegen müssen evangelion fans sein weil mein status für die wohl wie "do (not) disturb" aussieht
# ...

# %%
def search_twitter(query,tweet_fields,bearer_token='AAAAAAAAAAAAAAAAAAAAACXpZgEAAAAA23SiMgVzcRZO3l1ZaT7CZk0RFXU%3DQvqp85JU6n0Xk9UVEelN4nTfB4Xz8Lc9CGKCcLV7UAmNofxPew'):

    headers={'Authorization':'Bearer {}'.format(bearer_token)}
    url='https://api.twitter.com/2/tweets/search/recent?query={}&{}'.format(query,tweet_fields)
    response=requests.request("GET",url,headers=headers)
    print(response.status_code)
    
    if response.status_code !=200:
        raise Exception(response.status_code,response.text)
    return response.json()

# %%
query='Ironhack'
tweet_fields="tweet.fields=text"

# %%
import requests
import json

# %%
json_response = search_twitter(query=query, tweet_fields=tweet_fields, bearer_token='AAAAAAAAAAAAAAAAAAAAACXpZgEAAAAA23SiMgVzcRZO3l1ZaT7CZk0RFXU%3DQvqp85JU6n0Xk9UVEelN4nTfB4Xz8Lc9CGKCcLV7UAmNofxPew')
# Out:
# 200

# %%
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "id": "1498401006744440834",
#             "text": "Just posted a photo @ Ironhack US https://t.co/4HsNoMGV3I"
#         },
#         {
#             "id": "1498387623022407681",
#             "text": "Join us \ud83c\udf99 live inside the app w/ Kelli Carroll. Kelli is a Career Services Manager at IronHack. She will explain the differences between upskilling and reskilling, take your questions, and demonstrate why IronHack is a great place to attend a bootcamp!\n\nhttps://t.co/uQrhX3sYOw https://t.co/BXRFWhPQAH"
#         },
#         {
#             "id": "1498351597604200448",
#             "text": "RT @ChrisJCastle: W12 @ironhack: \n\n\ud83d\udd10more auth (bcrypt)\n\ud83d\udce7email verification (@nodemailer)\n\ud83c\udf0dgeolocation (@googlemaps)\n\ud83d\udec2social strategies (@pa\u2026"
#         },
#         {
#             "id": "1498350603646701568",
# ...

# %%
client=tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAACXpZgEAAAAA23SiMgVzcRZO3l1ZaT7CZk0RFXU%3DQvqp85JU6n0Xk9UVEelN4nTfB4Xz8Lc9CGKCcLV7UAmNofxPew')

# %%
query='ironhack'
tweets=client.search_recent_tweets(query=query, 
                                   tweet_fields=['context_annotations','created_at'],
                                   user_fields=['profile_image_url'], 
                                   expansions='author_id',max_results=100)

# %%
tweets
# Out:
# Response(data=[<Tweet id=1498401006744440834 text='Just posted a photo @ Ironhack US https://t.co/4HsNoMGV3I'>, <Tweet id=1498387623022407681 text='Join us 🎙 live inside the app w/ Kelli Carroll. Kelli is a Career Services Manager at IronHack. She will explain the differences between upskilling and reskilling, take your questions, and demonstrate why IronHack is a great place to attend a bootcamp!\n\nhttps://t.co/uQrhX3sYOw https://t.co/BXRFWhPQAH'>, <Tweet id=1498351597604200448 text='RT @ChrisJCastle: W12 @ironhack: \n\n🔐more auth (bcrypt)\n📧email verification (@nodemailer)\n🌍geolocation (@googlemaps)\n🛂social strategies (@pa…'>, <Tweet id=1498350603646701568 text='RT @ChrisJCastle: W12 @ironhack: \n\n🔐more auth (bcrypt)\n📧email verification (@nodemailer)\n🌍geolocation (@googlemaps)\n🛂social strategies (@pa…'>, <Tweet id=1498350578379988993 text='W12 @ironhack: \n\n🔐more auth (bcrypt)\n📧email verification (@nodemailer)\n🌍geolocation (@googlemaps)\n🛂social strategies (@passportjs)\n
# ...

# %%
tweets.includes
# Out:
# {}

# %%
users={u["id"]: u for u in tweets.includes['users']}

# %%
for tweet in tweets.data:
    if users[tweet.author_id]:
        users=users[tweet.author_id]
        print(user.profile_image_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ca552646c53f> in <module>
#       1 for tweet in tweets.data:
# ----> 2     if users[tweet.author_id]:
#       3         users=users[tweet.author_id]
#       4         print(user.profile_image_url)
#       5
#
# ~\anaconda3\lib\site-packages\tweepy\mixins.py in __getitem__(self, key)
#      37     def __getitem__(self, key):
#      38         try:
# ---> 39             return getattr(self, key)
#      40         except AttributeError:
#      41             raise KeyError from None
#
# TypeError: getattr(): attribute name must be string

# %%
import tweepy
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                    user_fields=['profile_image_url'], expansions='author_id', max_results=100)
# Get users list from the includes object
users = {u["id"]: u for u in tweets.includes['users']}
for tweet in tweets.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        print(user.profile_image_url)
# Out:
# https://pbs.twimg.com/profile_images/1481327639411499009/ccMjKRfq_normal.jpg
# https://pbs.twimg.com/profile_images/1027257809182777344/9Lb7PmQv_normal.jpg
# https://pbs.twimg.com/profile_images/898849819816595461/Pr79ok_o_normal.jpg
# https://pbs.twimg.com/profile_images/1459402333201199104/skHuHVT9_normal.jpg
# https://pbs.twimg.com/profile_images/1374532498047127554/4PSVvVuu_normal.jpg
# https://pbs.twimg.com/profile_images/1487033537371025410/QosaTHOC_normal.jpg
# https://pbs.twimg.com/profile_images/1415614749467947011/b03avJ7v_normal.jpg
# https://pbs.twimg.com/profile_images/1450742929333575681/CVO1fEjL_normal.jpg
# https://pbs.twimg.com/profile_images/1415614749467947011/b03avJ7v_normal.jpg
# https://pbs.twimg.com/profile_images/1450742929333575681/CVO1fEjL_normal.jpg
# https://pbs.twimg.com/profile_images/1415614749467947011/b03avJ7v_normal.jpg
# https://pbs.twimg.com/profile_images/662208870174072833/P2-ohI32_normal.jpg
# ...
