# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Labs\DAFT_212\module_2\Lab_10_Subsetting-and-Descriptive-Statistics\Temp_States.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
"""
your comments here
We only have one numerical series, encoding may be needed
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp[temp.State=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp[temp.State=='New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp[temp.Temperature>15.0]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp[['City','Temperature']].loc[temp['Temperature']>15]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
filt = (temp["Temperature"]>15) & (temp["Temperature"]<20)

temp.loc[filt]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code her
states=['New York', 'Connecticut', 'New Jersey']
for state in states:
    m=temp.loc[temp["State"]==state]['Temperature'].mean()
    s=temp.loc[temp["State"]==state]['Temperature'].std()
    print(f'{state}, mean: {m} stdev: {s}')
# Out:
# New York, mean: 10.74074074074074 stdev: 8.133404168888054
# Connecticut, mean: 15.833333333333332 stdev: 1.9641855032959645
# New Jersey, mean: 21.11111111111111 stdev: 1.5713484026367717

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Labs\DAFT_212\module_2\Lab_10_Subsetting-and-Descriptive-Statistics\Employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Department  500 non-null    object
#  1   Education   500 non-null    object
#  2   Title       500 non-null    object
#  3   Name        500 non-null    object
#  4   Years       500 non-null    int64
#  5   Salary      500 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
"""
your comments here
Mostly strings, years and salary are the only integer data
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees.sort_values(by='Salary').head(5)
# Out:
#     Department Education      Title  Name  Years  Salary
# 106      Admin  Bachelor  associate  Luke      4      30
# 214      Sales    Master         VP  Neil     11      30
# 27          IT  Bachelor    Analyst  Sean     12      30
# 128      Sales       PhD         VP  Adam      8      30
# 139      Sales       PhD    Analyst  Rick     11      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees.loc[employees.Name=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees['Salary'].loc[employees.Name=='David']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees.loc[employees.Title=='associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
associates=employees.loc[employees.Title=='associate']

# %%
# Method 1
# your code here
associates.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
associates.iloc[0:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
associates.loc[associates.Salary>55]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby('Years').agg('mean')
# Out:
#           Salary
# Years
# 1      75.863636
# 2      75.857143
# 3      74.571429
# 4      77.129032
# 5      73.857143
# 6      72.382353
# 7      73.840000
# 8      64.250000
# 9      76.741935
# 10     73.351351
# 11     74.866667
# 12     73.454545
# 13     71.935484
# 14     70.968750
# 15     69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees[['Title','Salary']].groupby('Title').agg('mean')
# Out:
#               Salary
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees['Salary'].describe()
# Out:
# count    500.000000
# mean      73.528000
# std       26.890061
# min       30.000000
# 25%       50.000000
# 50%       72.000000
# 75%       97.000000
# max      120.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees.columns

"""We do not have a gender column, therefore there is no quick way to know"""
# Out:
# Index(['Department', 'Education', 'Title', 'Name', 'Years', 'Salary'], dtype='object')

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
avg=employees[['Department','Years','Salary']].groupby('Department').agg('mean')
mini=employees[['Department','Years','Salary']].groupby('Department').agg('min')
maxi=employees[['Department','Years','Salary']].groupby('Department').agg('max')

# %%
avg
# Out:
#                Years     Salary
# Department
# Admin       7.642276  76.325203
# HR          7.172131  74.237705
# IT          8.141791  70.671642
# Sales       7.206612  73.132231

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Labs\DAFT_212\module_2\Lab_10_Subsetting-and-Descriptive-Statistics\Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  394343.000000  394343.000000  394343.000000  394343.000000
# mean   560639.243902    2010.934346       7.617752       3.614417
# std     13103.005872       0.247676       3.414434       1.927891
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549245.000000    2011.000000       5.000000       2.000000
# 50%    561898.000000    2011.000000       8.000000       3.000000
# 75%    572098.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  394343.000000  394343.000000  394343.000000  394343.000000
# mean       12.726745      12.796474       3.128340   15294.324923
# std         2.273834     127.261592      22.195292    1713.606332
# min         6.000000       1.000000       0.000000   12346.000000
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  object
#  1   InvoiceNo     394343 non-null  float64
#  2   StockCode     394343 non-null  object
#  3   year          394343 non-null  float64
#  4   month         394343 non-null  float64
#  5   day           394343 non-null  float64
#  6   hour          394343 non-null  float64
#  7   Description   394343 non-null  object
#  8   Quantity      394343 non-null  float64
#  9   InvoiceDate   394343 non-null  object
#  10  UnitPrice     394343 non-null  float64
#  11  CustomerID    394343 non-null  float64
#  12  Country       394343 non-null  object
#  13  amount_spent  394343 non-null  float64
# dtypes: float64(9), object(5)
# memory usage: 42.5+ MB

# %%
"""
your comments here
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders.UnitPrice.mean()
# Out:
# 3.1283395521108917

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
orders.UnitPrice.min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
spaniards=orders['CustomerID'].loc[orders['Country']=='Spain'].unique()

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
len(spaniards)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
qties=orders[['CustomerID','Quantity']].groupby('CustomerID').agg('sum')#.loc[orders['Quantity']>50]

# %%
fifty=qties.loc[qties.Quantity>50]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
cincuenta=orders[(orders['Country']=='Spain')& (orders['Quantity']>50)]

# %%
cincuenta
# Out:
#        Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 4250         6421   536944.0     22383  2010.0   12.0  5.0  12.0
# 4251         6422   536944.0     22384  2010.0   12.0  5.0  12.0
# 4252         6423   536944.0     20727  2010.0   12.0  5.0  12.0
# 4253         6424   536944.0     20725  2010.0   12.0  5.0  12.0
# 4254         6425   536944.0     20728  2010.0   12.0  5.0  12.0
# 32454       52416   540785.0    84997B  2011.0    1.0  2.0  11.0
# 32455       52417   540785.0    84997D  2011.0    1.0  2.0  11.0
# 32456       52418   540785.0    84997C  2011.0    1.0  2.0  11.0
# 32457       52419   540785.0    84997A  2011.0    1.0  2.0  11.0
# 91155      136767   547972.0     22383  2011.0    3.0  1.0  16.0
# 91156      136768   547972.0     22384  2011.0    3.0  1.0  16.0
# 91159      136771   547972.0     20728  2011.0    3.0  1.0  16.0
# 174442     248797   558871.0     22384  2011.0    7.0  1.0  13.0
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
free=orders[orders['amount_spent']==0]

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
lunch=orders.loc[orders['Description'].str.startswith('lunch bag')==True]
#lunch=lunch.loc[lunch['Description'].str.startswith('lunch bag')==True]

# %%
lunch
# Out:
#        Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 93             93   536378.0     20725  2010.0   12.0  3.0   9.0
# 172           174   536385.0     22662  2010.0   12.0  3.0   9.0
# 354           363   536401.0     22662  2010.0   12.0  3.0  11.0
# 359           368   536401.0     20725  2010.0   12.0  3.0  11.0
# 360           369   536401.0     22382  2010.0   12.0  3.0  11.0
# ...           ...        ...       ...     ...    ...  ...   ...
# 397465     540436   581486.0     23207  2011.0   12.0  5.0   9.0
# 397713     541695   581538.0     20727  2011.0   12.0  5.0  11.0
# 397714     541696   581538.0     20725  2011.0   12.0  5.0  11.0
# 397877     541862   581581.0     23681  2011.0   12.0  5.0  12.0
# 397880     541865   581583.0     20725  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot      10.0  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
lunch.loc[lunch.year==2011]
# Out:
#        Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 26340       42678   540015.0     20725  2011.0    1.0  2.0  11.0
# 26341       42679   540015.0     20726  2011.0    1.0  2.0  11.0
# 26512       42851   540023.0     22382  2011.0    1.0  2.0  12.0
# 26513       42852   540023.0     20726  2011.0    1.0  2.0  12.0
# 26860       43616   540098.0     22384  2011.0    1.0  2.0  15.0
# ...           ...        ...       ...     ...    ...  ...   ...
# 397465     540436   581486.0     23207  2011.0   12.0  5.0   9.0
# 397713     541695   581538.0     20727  2011.0   12.0  5.0  11.0
# 397714     541696   581538.0     20725  2011.0   12.0  5.0  11.0
# 397877     541862   581581.0     23681  2011.0   12.0  5.0  12.0
# 397880     541865   581583.0     20725  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot      10.0  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
frecuencia=orders.loc[orders.Country=='Spain']
frecuencia['amount_spent'].value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      98
# 17.40      86
# 10.20      74
#          ...
# 18.95       1
# 29.85       1
# 1.14        1
# 66.40       1
# 190.40      1
# Name: amount_spent, Length: 316, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
august=orders.loc[orders.month==8]

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
august['Country'].value_counts()
# Out:
# United Kingdom     22916
# Germany              792
# EIRE                 593
# France               568
# Netherlands          280
# Switzerland          266
# Spain                247
# Belgium              192
# Israel               169
# Channel Islands      138
# Australia            107
# Italy                 95
# Austria               87
# Norway                75
# Finland               60
# Malta                 54
# Portugal              41
# Sweden                39
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders[['Country','amount_spent']].groupby('Country').agg('mean')
# Out:
#                       amount_spent
# Country
# Australia               116.174809
# Austria                  25.702879
# Bahrain                  32.258824
# Belgium                  20.284055
# Brazil                   35.737500
# Canada                   24.487619
# Channel Islands          27.298978
# Cyprus                   22.134102
# Czech Republic           33.069600
# Denmark                  50.139309
# EIRE                     36.749535
# European Community       21.670833
# Finland                  33.098938
# France                   25.113201
# Germany                  25.329041
# Greece                   32.602917
# Iceland                  23.755801
# Israel                   29.311388
# Italy                    22.859305
# Japan                   117.226230
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.534324
# Netherlands             121.015705
# Norway                   33.684953
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders[['Description','UnitPrice']].sort_values(by='UnitPrice',ascending=False).head(1)
# Out:
#        Description  UnitPrice
# 118352     postage    8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders[['year','amount_spent']].groupby('year').agg('mean')
# Out:
#         amount_spent
# year
# 2010.0     21.940444
# 2011.0     22.041380
