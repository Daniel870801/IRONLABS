# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
# %matplotlib inline
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('label x')
plt.ylabel('label y')


plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1,ax2]=plt.subplots(1,2)

ax1.plot(x,y)

ax2.plot(x,z)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1,ax2]=plt.subplots(1,2,figsize=(5,5))


ax1.plot(x,y)
ax1.set_xlabel('x label',fontsize=10)
ax1.set_ylabel('y label',fontsize=8)

ax2.plot(x,z)
ax2.set_xlabel('x label',fontsize=10)
ax2.set_ylabel('y label',fontsize=8)

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code 
fig, [ax1,ax2]=plt.subplots(1,2,figsize=(5,5))


ax1.plot(x,x**2)
ax1.set_xlabel('x label',fontsize=10)
ax1.set_ylabel('y label',fontsize=8)

ax2.plot(x,np.e**x)
ax2.set_xlabel('x label',fontsize=10)
ax2.set_ylabel('y label',fontsize=8)
ax2.set_xscale('log')
ax2.set_yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Labs\DAFT_212\module_2\Lab_1_Matplotlib-and-Seaborn\Fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
months=fitbit.groupby(['Months_encoded']).agg({'Steps': np.median}).reset_index(inplace=True)

# %%
weekdays=fitbit.groupby(['Work_or_Weekend']).agg({'Steps': np.median})

# %%
weekdays.reset_index(inplace=True)

# %%
weekdays
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fig, [ax1,ax2]=plt.subplots(1,2,figsize=(12,4))
ax1.bar(months['Months_encoded'],months['Steps'])

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

ax2.bar(weekdays['Work_or_Weekend'],weekdays['Steps'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

fig, [ax1,ax2,ax3]=plt.subplots(1,3,figsize=(12,4))
study=[(ax1,'Minutes Lightly Active'),(ax2,'Minutes Very Active'),(ax3,'Minutes Sedentary')]

for ax in study:
    ax[0].scatter(fitbit['Steps'],fitbit[ax[1]])
    ax[0].set_xlabel('Steps',fontsize=10)
    ax[0].set_ylabel(ax[1],fontsize=8)
    
    
plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here.
titanic=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Labs\DAFT_212\module_2\Lab_1_Matplotlib-and-Seaborn\titanic.csv')

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['float64','int64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.style
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('classic')
plt.rcParams['figure.figsize']=(12,6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
bins=[10,20,50]
#titanic['Age'].plot.hist(bins=[10,20,50])
plt.hist(data = titanic, x = 'Age', bins = [10,20,50])
# Out:
# (array([162., 963.]), array([10, 20, 50]), <BarContainer object of 2 artists>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
import seaborn as sns

# %%
sns.histplot(data=titanic,x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
#plt.hist(titanic['Gender'])
titanic['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
# your code here
sns.histplot(data=titanic,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic['Pclass'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
titanic['Age'].value_counts()
# Out:
# 24.000000    47
# 22.000000    43
# 21.000000    41
# 30.000000    40
# 18.000000    39
#              ..
# 80.000000     1
# 46.914582     1
# 50.684299     1
# 35.076081     1
# 60.500000     1
# Name: Age, Length: 193, dtype: int64

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
The outliers are above 60, the average age is about 27.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic['Age'].plot(kind='box')
plt.show()

sns.displot(x=titanic['Age'],data=titanic)

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

plt.scatter('Fare','Age',data=titanic)

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot('Fare','Age',data=titanic,hue='Age')
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Passenger class and fare appear to be negatively correlated, which is not surprising (class 3 will be the cheapest)
Age and Passenger class appear to be negatively correlated, so we could assume that the younger, the cheaper fare they bought

Age is also correlated positively to Survived. The younger the more resistant to cold?
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.kdeplot(x='Pclass',y='Age',data=titanic,shade=True)
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g=sns.FacetGrid(titanic,col='Gender')
g.map(plt.hist, 'Age')
