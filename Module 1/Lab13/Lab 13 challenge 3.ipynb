# %%
import json
import requests

# %%
response = requests.get('https://jsonplaceholder.typicode.com/todos')
response.status_code
results = response.json()

# %%
import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
print(response.status_code)
# Out:
# 200

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(1)
# Out:
#             id       type                                              actor  \
# 0  20514161609  PushEvent  {'id': 41821328, 'login': 'mshilenkov', 'displ...
#
#                                                 repo  \
# 0  {'id': 461446520, 'name': 'mshilenkov/DevOps',...
#
#                                              payload  public  \
# 0  {'push_id': 9231480912, 'size': 1, 'distinct_s...    True
#
#              created_at  org
# 0  2022-03-01T10:01:05Z  NaN

# %%
flattened_data = pd.json_normalize(response.json())

flattened_data.head(1)
# Out:
#             id       type  public            created_at  actor.id actor.login  \
# 0  20514161609  PushEvent    True  2022-03-01T10:01:05Z  41821328  mshilenkov
#
#   actor.display_login actor.gravatar_id  \
# 0          mshilenkov
#
#                                  actor.url  \
# 0  https://api.github.com/users/mshilenkov
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/41821328?  ...
#
#    payload.forkee.is_template payload.forkee.topics payload.forkee.visibility  \
# 0                         NaN                   NaN                       NaN
#
#    payload.forkee.forks  payload.forkee.open_issues  payload.forkee.watchers  \
# 0                   NaN                         NaN                      NaN
#
#   payload.forkee.default_branch payload.forkee.public  \
# 0                           NaN                   NaN
#
#   payload.pull_request.head.repo.license  \
# 0                                    NaN
#
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)


flat.head(10)
# Out:
#             id               type  public            created_at   actor_id  \
# 0  20514161609          PushEvent    True  2022-03-01T10:01:05Z   41821328
# 1  20514161602   PullRequestEvent    True  2022-03-01T10:01:05Z   49699333
# 2  20514161587          PushEvent    True  2022-03-01T10:01:05Z  100557909
# 3  20514161563          PushEvent    True  2022-03-01T10:01:05Z    1288133
# 4  20514161605  IssueCommentEvent    True  2022-03-01T10:01:05Z   10762218
# 5  20514161597        DeleteEvent    True  2022-03-01T10:01:05Z     360803
# 6  20514161551        DeleteEvent    True  2022-03-01T10:01:05Z   49699333
# 7  20514161529          PushEvent    True  2022-03-01T10:01:05Z   61080956
# 8  20514161544          PushEvent    True  2022-03-01T10:01:05Z   92025208
# 9  20514161510         WatchEvent    True  2022-03-01T10:01:05Z   25196178
#
#                  actor_login        actor_display_login actor_gravatar_id  \
# 0                 mshilenkov                 mshilenkov
# ...

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search
# Out:
# {'total_count': 0, 'incomplete_results': False, 'items': []}

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/forks', auth=('Daniel870801', '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'));
data = response.json()

# %%
flattened_data = pd.json_normalize(response.json())

# %%
flattened_data.head(10)
# Out:
#           id                           node_id       name  \
# 0  464526848                      R_kgDOG7AeAA  scavenger
# 1  464524061                      R_kgDOG7ATHQ  scavenger
# 2  435516877                      R_kgDOGfV1zQ  scavenger
# 3  435516822                      R_kgDOGfV1lg  scavenger
# 4  427753460                      R_kgDOGX7_9A  scavenger
# 5  367701764  MDEwOlJlcG9zaXRvcnkzNjc3MDE3NjQ=  scavenger
# 6  367701743  MDEwOlJlcG9zaXRvcnkzNjc3MDE3NDM=  scavenger
# 7  353795570  MDEwOlJlcG9zaXRvcnkzNTM3OTU1NzA=  scavenger
# 8  331967534  MDEwOlJlcG9zaXRvcnkzMzE5Njc1MzQ=  scavenger
# 9  311530965  MDEwOlJlcG9zaXRvcnkzMTE1MzA5NjU=  scavenger
#
#                 full_name  private                                   html_url  \
# 0      Gixi0612/scavenger    False      https://github.com/Gixi0612/scavenger
# 1      aiolii63/scavenger    False      https://github.com/aiolii63/scavenger
# 2      akcortes/scavenger    False      https://github.com/akcortes/scavenger
# ...

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/forks', auth=('Daniel870801', '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'));
data = response.json()

# %%
data
# Out:
# [{'id': 464526848,
#   'node_id': 'R_kgDOG7AeAA',
#   'name': 'scavenger',
#   'full_name': 'Gixi0612/scavenger',
#   'private': False,
#   'owner': {'login': 'Gixi0612',
#    'id': 92369109,
#    'node_id': 'U_kgDOBYFw1Q',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92369109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gixi0612',
#    'html_url': 'https://github.com/Gixi0612',
#    'followers_url': 'https://api.github.com/users/Gixi0612/followers',
#    'following_url': 'https://api.github.com/users/Gixi0612/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Gixi0612/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Gixi0612/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Gixi0612/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Gixi0612/orgs',
#    'repos_url': 'https://api.github.com/users/Gixi0612/repos',
# ...

# %%
flattened_data = pd.json_normalize(response.json())

# %%
flattened_data['url']
# Out:
# 0       https://api.github.com/repos/Gixi0612/scavenger
# 1       https://api.github.com/repos/aiolii63/scavenger
# 2       https://api.github.com/repos/akcortes/scavenger
# 3         https://api.github.com/repos/ouykhy/scavenger
# 4     https://api.github.com/repos/chavichongo/scave...
# 5       https://api.github.com/repos/rmaldonh/scavenger
# 6       https://api.github.com/repos/Covs2993/scavenger
# 7      https://api.github.com/repos/carazaagu/scavenger
# 8     https://api.github.com/repos/Guilhermegcz/scav...
# 9     https://api.github.com/repos/patocuak08/scavenger
# 10      https://api.github.com/repos/Cand0427/scavenger
# 11      https://api.github.com/repos/Lauminja/scavenger
# 12     https://api.github.com/repos/orianegsx/scavenger
# 13     https://api.github.com/repos/diequicar/scavenger
# 14       https://api.github.com/repos/EiroaMD/scavenger
# Name: url, dtype: object

# %%
flattened_data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search
# Out:
# {'total_count': 0, 'incomplete_results': False, 'items': []}

# %%
search['items']
# Out:
# []

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
files=search['items']

# %%
files
# Out:
# [{'name': '.0016.scavengerhunt',
#   'path': '47222/.0016.scavengerhunt',
#   'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
files=sorted(files,key=lambda file: file['name'])

# %%
print(files)
# Out:
# [{'name': '.0001.scavengerhunt', 'path': '98750/.0001.scavengerhunt', 'sha': '2add7632f1323136324efbf38ec66db1838b6173', 'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.git
# ...

# %%
contents_list=[]
headers = {'Accept': 'application/vnd.github.v3.raw', };
headers
# Out:
# {'Accept': 'application/vnd.github.v3.raw'}

# %%
for file in files:
    content_path = ('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}').format(file['path']);
    response = requests.get(content_path, headers=headers);
    contents_list.append(response.text)

# %%
print(contents_list)
# Out:
# ['In\n', 'data\n', '{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}\n', '{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}\n', '{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}\n', '{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a hig
# ...

# %%
dirt=['{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}\n', '{"message":"API rate limit exceeded for 195.134.167.217. (But here\'s the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}\n']
clean_list=[]
for content in contents_list:
    if content not in dirt:
        clean_list.append(content)
    else:
        continue

# %%
print(clean_list)
# Out:
# ['In\n', 'data\n', 'In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']

# %%
clean_list=[i.strip() for i in clean_list]
final_answer=' '.join(clean_list)

# %%
final_answer
# Out:
# 'In data In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
